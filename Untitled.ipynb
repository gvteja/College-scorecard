# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./MERGED2011_PP.csv')

# %%
df['dev-category']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-14b0401fb971> in <module>()
# ----> 1 df['dev-category']
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# ...

# %%
inc=df[['mn_earn_wne_inc1_p10',
'mn_earn_wne_inc2_p10',
'mn_earn_wne_inc3_p10']]

# %%
inc.describe()
# Out:
#        mn_earn_wne_inc1_p10 mn_earn_wne_inc2_p10 mn_earn_wne_inc3_p10
# count                  6738                 6738                 6738
# unique                  492                  472                  453
# top       PrivacySuppressed    PrivacySuppressed    PrivacySuppressed
# freq                   3221                 3220                 3462

# %%
for col in df.columns:
    print col
# Out:
# ﻿UNITID
# OPEID
# opeid6
# INSTNM
# CITY
# STABBR
# ZIP
# AccredAgency
# INSTURL
# NPCURL
# sch_deg
# HCM2
# main
# NUMBRANCH
# PREDDEG
# HIGHDEG
# CONTROL
# st_fips
# region
# LOCALE
# locale2
# LATITUDE
# LONGITUDE
# CCBASIC
# CCUGPROF
# CCSIZSET
# HBCU
# PBI
# ANNHI
# TRIBAL
# AANAPII
# HSI
# NANTI
# MENONLY
# WOMENONLY
# RELAFFIL
# ADM_RATE
# ADM_RATE_ALL
# SATVR25
# SATVR75
# SATMT25
# SATMT75
# SATWR25
# SATWR75
# SATVRMID
# SATMTMID
# SATWRMID
# ACTCM25
# ACTCM75
# ACTEN25
# ACTEN75
# ACTMT25
# ACTMT75
# ACTWR25
# ACTWR75
# ACTCMMID
# ACTENMID
# ACTMTMID
# ACTWRMID
# SAT_AVG
# SAT_AVG_ALL
# PCIP01
# PCIP03
# PCIP04
# PCIP05
# PCIP09
# PCIP10
# PCIP11
# PCIP12
# PCIP13
# PCIP14
# PCIP15
# PCIP16
# PCIP19
# PCIP22
# PCIP23
# PCIP24
# PCIP25
# PCIP26
# PCIP27
# PCIP29
# PCIP30
# PCIP31
# PCIP38
# PCIP39
# PCIP40
# PCIP41
# PCIP42
# PCIP43
# PCIP44
# PCIP45
# PCIP46
# PCIP47
# PCIP48
# PCIP49
# PCIP50
# PCIP51
# PCIP52
# PCIP54
# CIP01CERT1
# CIP01CERT2
# CIP01ASSOC
# CIP01CERT4
# ...

# %%
cost=df[['COSTT4_A',
'COSTT4_P']]

# %%
df['dev-category']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-14b0401fb971> in <module>()
# ----> 1 df['dev-category']
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1082         res = cache.get(item)
#    1083         if res is None:
# ...
